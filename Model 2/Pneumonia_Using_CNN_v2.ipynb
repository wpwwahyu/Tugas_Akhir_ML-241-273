jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person930_bacteria_2855.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person931_bacteria_2856.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person931_virus_1592.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person932_virus_1593.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person933_bacteria_2858.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person933_virus_1594.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person934_bacteria_2859.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person934_virus_1595.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person935_virus_1597.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person936_bacteria_2861.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person936_virus_1598.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person937_bacteria_2862.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person937_virus_1599.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person938_bacteria_2863.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person938_virus_1600.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person939_bacteria_2864.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person93_bacteria_453.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person93_bacteria_454.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person93_virus_175.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person940_bacteria_2865.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person940_virus_1602.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person940_virus_1604.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person940_virus_1605.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person940_virus_1607.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person940_virus_1609.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person941_virus_1610.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person942_bacteria_2867.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person942_virus_1611.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person943_bacteria_2868.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person944_bacteria_2869.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person945_bacteria_2870.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person945_virus_1616.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person946_bacteria_2871.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person947_bacteria_2872.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person947_virus_1618.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person949_bacteria_2874.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person949_virus_1620.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person94_bacteria_456.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person94_bacteria_457.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person94_bacteria_458.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person94_virus_176.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person950_virus_1621.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person951_bacteria_2876.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person951_virus_1622.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person952_bacteria_2877.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person952_virus_1623.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person953_bacteria_2878.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person954_bacteria_2879.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person954_virus_1626.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person955_bacteria_2880.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person955_virus_1627.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person956_bacteria_2881.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person956_virus_1628.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person957_bacteria_2882.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person957_virus_1629.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person958_bacteria_2883.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person958_virus_1630.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person959_bacteria_2884.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person95_bacteria_463.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person95_virus_177.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person960_bacteria_2885.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person960_virus_1633.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person961_bacteria_2886.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person961_virus_1634.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person962_bacteria_2887.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person962_virus_1635.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person963_bacteria_2888.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person963_virus_1636.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person964_bacteria_2889.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person964_virus_1637.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person965_bacteria_2890.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person965_virus_1638.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person966_bacteria_2891.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person966_virus_1639.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person967_bacteria_2892.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person967_virus_1640.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person968_bacteria_2893.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person968_virus_1642.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person969_bacteria_2894.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person969_virus_1643.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person96_bacteria_464.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person96_bacteria_465.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person96_bacteria_466.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person96_virus_178.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person96_virus_179.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person970_bacteria_2895.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person970_virus_1644.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person971_bacteria_2896.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person972_bacteria_2897.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person972_virus_1646.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person973_virus_1647.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person974_bacteria_2899.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person974_virus_1649.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person975_virus_1650.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person976_bacteria_2901.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person976_virus_1651.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person977_bacteria_2902.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person977_virus_1652.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person978_bacteria_2904.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person978_virus_1653.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person979_bacteria_2905.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person979_virus_1654.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person97_bacteria_468.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person97_virus_180.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person97_virus_181.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person980_bacteria_2906.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person980_virus_1655.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person981_bacteria_2907.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person981_bacteria_2908.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person981_virus_1657.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person982_bacteria_2909.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person982_virus_1658.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person983_bacteria_2910.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person983_virus_1660.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person984_bacteria_2911.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person985_bacteria_2912.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person986_bacteria_2913.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person987_bacteria_2914.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person988_bacteria_2915.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person988_virus_1666.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person989_virus_1667.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person98_virus_182.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person990_bacteria_2917.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person991_bacteria_2918.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person991_virus_1669.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person992_bacteria_2919.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person992_bacteria_2920.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person992_virus_1670.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person993_bacteria_2921.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person993_virus_1671.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person994_bacteria_2922.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person994_virus_1672.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person995_bacteria_2923.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person995_virus_1676.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person996_bacteria_2924.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person996_virus_1677.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person997_bacteria_2926.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person997_virus_1678.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person998_bacteria_2927.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person998_bacteria_2928.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person99_bacteria_473.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person99_bacteria_474.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person99_virus_183.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person9_bacteria_38.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person9_bacteria_39.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person9_bacteria_40.jpeg
#   inflating: /content/drive/MyDrive/ml/chest_xray/PNEUMONIA/person9_bacteria_41.jpeg

# %%
# Cek isi direktori kerja untuk memastikan dataset telah berhasil diekstrak.
# !ls
# Out:
# chest_xray  split_folder_ml_pneumonia

# %%
import os
base_dataset = "chest_xray"
class_dir = ['NORMAL', 'PNEUMONIA']
for class_item in class_dir:
  cur_dir = base_dataset+"/"+class_item
  dataset = os.listdir(cur_dir)
  for item in dataset:
    if not item.endswith(".jpeg"):
        os.remove(os.path.join(cur_dir, item))

# %%
# !pip install split_folders
import splitfolders
# Out:
# Collecting split_folders
#   Downloading split_folders-0.4.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %%
#untuk menetapkan directory

input_folder = "/content/drive/MyDrive/ml/chest_xray"
base_dir = "/content/drive/MyDrive/ml/split_folder_ml_pneumonia"

# %%
splitfolders.ratio(input_folder, output = base_dir, seed=1337, ratio=(0.80,0.19,0.01))
# Out:
# Copying files: 5856 files [01:07, 87.20 files/s]

# %%
import os
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

train_normal_dir = os.path.join(train_dir, 'NORMAL')
train_pneumonia_dir = os.path.join(train_dir, 'PNEUMONIA')

validation_normal_dir = os.path.join(validation_dir, 'NORMAL')
validation_pneumonia_dir = os.path.join(validation_dir, 'PNEUMONIA')

test_normal_dir = os.path.join(test_dir, 'NORMAL')
test_pneumonia_dir = os.path.join(test_dir, 'PNEUMONIA')

# %%
print('Train NORMAL :', os.listdir(train_normal_dir)[:10])
print('Train PNEUMONIA :', os.listdir(train_pneumonia_dir)[:10])
print("\n")

print('Validation NORMAL :', os.listdir(validation_normal_dir)[:10])
print('Validation PNEUMONIA :', os.listdir(validation_pneumonia_dir)[:10])
print("\n")

print('Test NORMAL :', os.listdir(test_normal_dir)[:10])
print('Test PNEUMONIA :', os.listdir(test_pneumonia_dir)[:10])
# Out:
# Train NORMAL : ['IM-0249-0001.jpeg', 'IM-0250-0001.jpeg', 'IM-0277-0001.jpeg', 'IM-0243-0001.jpeg', 'IM-0299-0001.jpeg', 'IM-0316-0001.jpeg', 'IM-0314-0001.jpeg', 'IM-0297-0001.jpeg', 'IM-0293-0001.jpeg', 'IM-0295-0001.jpeg']
# Train PNEUMONIA : ['person515_bacteria_2190.jpeg', 'person500_bacteria_2105.jpeg', 'person467_bacteria_1989.jpeg', 'person51_bacteria_247.jpeg', 'person505_bacteria_2135.jpeg', 'person491_bacteria_2073.jpeg', 'person520_bacteria_2203.jpeg', 'person490_bacteria_2068.jpeg', 'person491_bacteria_2075.jpeg', 'person511_bacteria_2152.jpeg']
#
#
# Validation NORMAL : ['IM-0019-0001.jpeg', 'IM-0009-0001.jpeg', 'IM-0001-0001.jpeg', 'NORMAL2-IM-0028-0001.jpeg', 'IM-0091-0001.jpeg', 'IM-0049-0001.jpeg', 'NORMAL2-IM-0060-0001.jpeg', 'IM-0043-0001.jpeg', 'IM-0050-0001.jpeg', 'IM-0083-0001.jpeg']
# Validation PNEUMONIA : ['person130_bacteria_623.jpeg', 'person108_bacteria_507.jpeg', 'person158_bacteria_743.jpeg', 'person124_bacteria_589.jpeg', 'person113_bacteria_540.jpeg', 'person146_bacteria_703.jpeg', 'person153_bacteria_726.jpeg', 'person139_bacteria_661.jpeg', 'person119_bacteria_566.jpeg', 'person128_bacteria_605.jpeg']
#
#
# Test NORMAL : ['NORMAL2-IM-0058-0001.jpeg', 'NORMAL2-IM-0325-0001.jpeg', 'NORMAL2-IM-0246-0001-0002.jpeg', 'NORMAL2-IM-0276-0001.jpeg', 'NORMAL2-IM-0343-0001.jpeg', 'IM-0471-0001.jpeg', 'IM-0531-0001-0001.jpeg', 'IM-0715-0001.jpeg', 'NORMAL2-IM-0780-0001.jpeg', 'NORMAL2-IM-0876-0001.jpeg']
# Test PNEUMONIA : ['person135_bacteria_646.jpeg', 'person154_bacteria_728.jpeg', 'person1661_virus_2873.jpeg', 'person63_virus_121.jpeg', 'person71_virus_131.jpeg', 'person1673_virus_2889.jpeg', 'person56_virus_112.jpeg', 'person1072_virus_1775.jpeg', 'person1051_bacteria_2985.jpeg', 'person1075_bacteria_3015.jpeg']

# %%
# Tampilkan 8 image per kelas dengan ukuran 4x4 

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 2
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches( ncols * 4,nrows * 4)

pic_index += 8

train_normal = [os.path.join(train_normal_dir, fname) 
                for fname in os.listdir(train_normal_dir)[pic_index-4:pic_index]]

train_pneumonia = [os.path.join(train_pneumonia_dir, fname) 
                for fname in os.listdir(train_pneumonia_dir)[pic_index-4:pic_index]]

for i, img_path in enumerate(train_normal+train_pneumonia):
    
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)
  plt.title(img_path.split(os.path.sep)[-2])

plt.show()

# %%
print('Train NORMAL :', len(os.listdir(train_normal_dir)))
print('Train PNEUMONIA :', len(os.listdir(train_pneumonia_dir)))
print("\n")

print('Validation NORMAL :', len(os.listdir(validation_normal_dir)))
print('Validation PNEUMONIA :', len(os.listdir(validation_pneumonia_dir)))
print("\n")

print('Test NORMAL :', len(os.listdir(test_normal_dir)))
print('Test PNEUMONIA :', len(os.listdir(test_pneumonia_dir)))
# Out:
# Train NORMAL : 1266
# Train PNEUMONIA : 3418
#
#
# Validation NORMAL : 300
# Validation PNEUMONIA : 811
#
#
# Test NORMAL : 17
# Test PNEUMONIA : 44

# %%
import matplotlib.pyplot as plt 
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau

# import library to build our model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model
#from tensorflow.keras.applications.vgg16 import preprocess_input

# plotting
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np

# %%
height = 200
width = 200
batch_size = 32

generator_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range = 40,
    height_shift_range= 0.2,
    width_shift_range= 0.2,
    horizontal_flip=True)

val_gen = ImageDataGenerator(rescale = 1./255)

train_generator = generator_datagen.flow_from_directory(
    train_dir,
    target_size=(height, width),
    class_mode='binary',
    color_mode="rgb",
    shuffle=True,
    batch_size=batch_size
)

validation_generator = val_gen.flow_from_directory(
    validation_dir,
    target_size=(height,width),
    class_mode='binary',
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size
)

test_generator = val_gen.flow_from_directory(
    test_dir,
    target_size=(height,width),
    class_mode='binary',
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size
)
# Out:
# Found 4684 images belonging to 2 classes.
# Found 1111 images belonging to 2 classes.
# Found 61 images belonging to 2 classes.

# %%
import cv2
import numpy as np

# Gather data train
train_data = []
train_label = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpeg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (200,200))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
# Gather data validation
val_data = []
val_label = []
for r, d, f in os.walk(validation_dir):
    for file in f:
        if ".jpeg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (200,200))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %%
# Gather data test
test_data = []
test_label = []
for r, d, f in os.walk(test_dir):
    for file in f:
        if ".jpeg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (200,200))
            test_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            test_label.append(label)

test_data = np.array(test_data)
test_label = np.array(test_label)

# %%
# Tampilkan shape dari data train dan data validation
print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)
print("Test Data = ", test_data.shape)
print("Test Label = ", test_label.shape)
# Out:
# Train Data =  (4684, 200, 200, 3)
# Train Label =  (4684,)
# Validation Data =  (1111, 200, 200, 3)
# Validation Label =  (1111,)
# Test Data =  (61, 200, 200, 3)
# Test Label =  (61,)

# %%
# Normalisasi dataset
print("Data sebelum di-normalisasi ", train_data[0][0][0])

x_train = train_data.astype('float32') / 255.0
x_test = test_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [73 73 73]
# Data setelah di-normalisasi  [0.28627452 0.28627452 0.28627452]

# %%
# Transformasi label encoder
from sklearn.preprocessing import LabelEncoder

print("Label sebelum di-encoder ", train_label[1200:1203])
print("Label sebelum di-encoder ", train_label[2343:2346])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_test = lb.fit_transform(test_label)
y_val = lb.fit_transform(val_label)

print("Label setelah di-encoder ", y_train[1200:1203])
print("Label setelah di-encoder ", y_train[2343:2346])
# Out:
# Label sebelum di-encoder  ['NORMAL' 'NORMAL' 'NORMAL']
# Label sebelum di-encoder  ['PNEUMONIA' 'PNEUMONIA' 'PNEUMONIA']
# Label setelah di-encoder  [0 0 0]
# Label setelah di-encoder  [1 1 1]

# %%
x_train.shape
# Out:
# (4684, 200, 200, 3)

# %%
x_val.shape
# Out:
# (1111, 200, 200, 3)

# %%
x_test.shape
# Out:
# (61, 200, 200, 3)

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import InputLayer, Dense, Dropout, Conv2D, MaxPool2D, MaxPooling2D, GlobalMaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Flatten, BatchNormalization

# %%
DESIRED_ACCURACY = 0.95

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epochs, logs={}) :
        if(logs.get('acc') is not None and logs.get('acc') >= DESIRED_ACCURACY) :
            print('\nReached 95% accuracy so cancelling training!')
            self.model.stop_training = True

callbacks = myCallback()

# %% [markdown]
# ##Model 2

# %%
# DEFINISIKAN MODEL ANDA DISINI
model = Sequential()

model.add(InputLayer(input_shape=[200,200,3]))

model.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(Flatten())

model.add(Dropout(0.5))

# Fully Connected Layer
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 200, 200, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 100, 100, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 25, 25, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 80000)             0
#
#  dropout (Dropout)           (None, 80000)             0
#
#  dense (Dense)               (None, 512)               40960512
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 41,054,273
# Trainable params: 41,054,273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['acc'])

history = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
#
50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0028 - acc: 0.9991 - val_loss: 0.3347 - val_acc: 0.9508
# Epoch 36/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0025 - acc: 0.9991 - val_loss: 0.3566 - val_acc: 0.9508
# Epoch 37/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0028 - acc: 0.9987 - val_loss: 0.3307 - val_acc: 0.9672
# Epoch 38/50
# 147/147 [==============================] - 7s 50ms/step - loss: 0.0101 - acc: 0.9964 - val_loss: 0.3168 - val_acc: 0.9508
# Epoch 39/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0084 - acc: 0.9964 - val_loss: 0.2972 - val_acc: 0.9672
# Epoch 40/50
# 147/147 [==============================] - 7s 50ms/step - loss: 0.0019 - acc: 0.9994 - val_loss: 0.3700 - val_acc: 0.9672
# Epoch 41/50
# 147/147 [==============================] - 7s 50ms/step - loss: 0.0067 - acc: 0.9977 - val_loss: 0.2625 - val_acc: 0.9672
# Epoch 42/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0134 - acc: 0.9953 - val_loss: 0.1643 - val_acc: 0.9672
# Epoch 43/50
# 147/147 [==============================] - 7s 50ms/step - loss: 0.0048 - acc: 0.9985 - val_loss: 0.2073 - val_acc: 0.9672
# Epoch 44/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0035 - acc: 0.9994 - val_loss: 0.2021 - val_acc: 0.9672
# Epoch 45/50
# 147/147 [==============================] - 7s 50ms/step - loss: 8.6463e-04 - acc: 1.0000 - val_loss: 0.3709 - val_acc: 0.9672
# Epoch 46/50
# 147/147 [==============================] - 7s 50ms/step - loss: 0.0198 - acc: 0.9938 - val_loss: 0.3279 - val_acc: 0.9672
# Epoch 47/50
# 147/147 [==============================] - 7s 50ms/step - loss: 0.0117 - acc: 0.9959 - val_loss: 0.2045 - val_acc: 0.9672
# Epoch 48/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0019 - acc: 0.9996 - val_loss: 0.2293 - val_acc: 0.9672
# Epoch 49/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0015 - acc: 0.9994 - val_loss: 0.3541 - val_acc: 0.9672
# Epoch 50/50
# 147/147 [==============================] - 7s 49ms/step - loss: 0.0064 - acc: 0.9974 - val_loss: 0.2868 - val_acc: 0.9836

# %%
# summarize history for accuracy
# %matplotlib inline

import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
plt.xticks(fontsize='15')
plt.yticks(fontsize='15') 
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy', fontsize=15)
plt.ylabel('accuracy', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(['train', 'validation'], loc='upper left', fontsize=15)
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.xticks(fontsize='15')
plt.yticks(fontsize='15') 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', fontsize=15)
plt.ylabel('loss', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(['train', 'validation'], loc='upper left', fontsize=15)
plt.show()

# %%
model.save('/content/drive/MyDrive/Pneumonia Dataset/Model/BatchNormModelCNN.h5')
model.save('/content/drive/MyDrive/Pneumonia Dataset/Model/DropoutModelCNN.h5')

# %%
from sklearn.metrics import classification_report

# %%
from keras.models import load_model

# load model pertama
target_dir = '/content/drive/MyDrive/Pneumonia Dataset/Model'
model_saved = load_model(target_dir + '/BatchNormModelCNN.h5')

# %%
target_names = []
for key in train_generator.class_indices:
    target_names.append(key)
print(target_names)
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
from sklearn.metrics import classification_report

predictions = model.predict(x_test)
predictions = np.round(predictions).astype(int)

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        17
#            1       1.00      0.98      0.99        44
#
#     accuracy                           0.98        61
#    macro avg       0.97      0.99      0.98        61
# weighted avg       0.98      0.98      0.98        61

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):

    """

    This function prints and plots the confusion matrix.

    Normalization can be applied by setting `normalize=True`.

    """

    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))

    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
target_names = []

for key in train_generator.class_indices:
    target_names.append(key)

# %%
from sklearn.metrics import  confusion_matrix
import itertools

pred = model.predict(test_generator)
labels = np.argmax(pred, axis=1)

print('Confusion Matrix')
cm = confusion_matrix(test_generator.classes, labels)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
# Out:
# Confusion Matrix
# Normalized confusion matrix
